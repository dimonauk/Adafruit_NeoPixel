# %%
#@markdown Check type of GPU and VRAM available.
# !nvidia-smi --query-gpu=name,memory.total,memory.free --format=csv,noheader
# Out:
# Tesla T4, 15109 MiB, 15109 MiB

# %% [markdown]
# https://github.com/ShivamShrirao/diffusers/tree/main/examples/dreambooth

# %% [markdown]
# ## Install Requirements

# %%
# !wget -q https://github.com/ShivamShrirao/diffusers/raw/main/examples/dreambooth/train_dreambooth.py
# %pip install -q git+https://github.com/ShivamShrirao/diffusers
# %pip install -q -U --pre triton
# %pip install -q accelerate transformers ftfy bitsandbytes gradio
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
#      |████████████████████████████████| 163 kB 29.7 MB/s
#   Building wheel for diffusers (PEP 517) ... done
#      |████████████████████████████████| 18.7 MB 360 kB/s
#      |████████████████████████████████| 143 kB 25.3 MB/s
#      |████████████████████████████████| 4.9 MB 54.1 MB/s
#      |████████████████████████████████| 53 kB 1.9 MB/s
#      |████████████████████████████████| 55.9 MB 181 kB/s
#      |████████████████████████████████| 5.3 MB 54.1 MB/s
#      |████████████████████████████████| 6.6 MB 51.8 MB/s
#      |████████████████████████████████| 84 kB 3.9 MB/s
#      |████████████████████████████████| 84 kB 648 kB/s
#      |████████████████████████████████| 57 kB 5.7 MB/s
#      |████████████████████████████████| 54 kB 3.3 MB/s
#      |████████████████████████████████| 212 kB 71.7 MB/s
#      |████████████████████████████████| 112 kB 70.7 MB/s
#      |████████████████████████████████| 270 kB 76.2 MB/s
#      |████████████████████████████████| 55 kB 3.8 MB/s
#      |████████████████████████████████| 2.3 MB 62.1 MB/s
#      |████████████████████████████████| 63 kB 2.7 MB/s
#      |████████████████████████████████| 80 kB 9.1 MB/s
#      |████████████████████████████████| 68 kB 7.4 MB/s
#      |████████████████████████████████| 46 kB 4.6 MB/s
#      |████████████████████████████████| 594 kB 68.6 MB/s
#      |████████████████████████████████| 4.0 MB 54.3 MB/s
#      |████████████████████████████████| 856 kB 58.4 MB/s
#   Building wheel for ffmpy (setup.py) ... done
#   Building wheel for python-multipart (setup.py) ... done

# %% [markdown]
# ### Install xformers from precompiled wheel.

# %%
# %pip install -q https://github.com/metrolobo/xformers_wheels/releases/download/1d31a3ac_various_6/xformers-0.0.14.dev0-cp37-cp37m-linux_x86_64.whl
# These were compiled on Tesla T4, should also work on P100, thanks to https://github.com/metrolobo

# If precompiled wheels don't work, install it with the following command. It will take around 40 minutes to compile.
# %pip install git+https://github.com/facebookresearch/xformers@1d31a3a#egg=xformers
# Out:
#      |████████████████████████████████| 102.9 MB 85 kB/s

# %% [markdown]
# ## Login to HF and run

# %%
#@markdown Login to HuggingFace 🤗

#@markdown You need to accept the model license before downloading or using the Stable Diffusion weights. Please, visit the [model card](https://huggingface.co/CompVis/stable-diffusion-v1-4), read the license and tick the checkbox if you agree. You have to be a registered user in 🤗 Hugging Face Hub, and you'll also need to use an access token for the code to work.
from huggingface_hub import notebook_login
# !git config --global credential.helper store
notebook_login()
# Out:
# Login successful
# Your token has been saved to /root/.huggingface/token

# %%
#@markdown Name/Path of the initial model.
MODEL_NAME = "CompVis/stable-diffusion-v1-4" #@param {type:"string"}

#@markdown Path for images of the concept for training.
INSTANCE_DIR = "/content/data/sks" #@param {type:"string"}
# !mkdir -p $INSTANCE_DIR

#@markdown A general name for class like dog for dog images.
CLASS_NAME = "woman" #@param {type:"string"}
CLASS_DIR = f"/content/data/{CLASS_NAME}"

#@markdown If model weights should be saved directly in google drive (takes around 4-5 GB).
save_to_gdrive = True #@param {type:"boolean"}
if save_to_gdrive:
    from google.colab import drive
    drive.mount('/content/drive')

#@markdown Enter the directory name to save model at.

OUTPUT_DIR = "stable_diffusion_weights/sks" #@param {type:"string"}
if save_to_gdrive:
    OUTPUT_DIR = "/content/drive/MyDrive/" + OUTPUT_DIR
else:
    OUTPUT_DIR = "/content/" + OUTPUT_DIR

print(f"[*] Weights will be saved at {OUTPUT_DIR}")

# !mkdir -p $OUTPUT_DIR

#@markdown sks is a rare identifier, feel free to replace it.
# Out:
# Mounted at /content/drive
# [*] Weights will be saved at /content/drive/MyDrive/stable_diffusion_weights/sks

# %%
#@markdown Upload your (5-6) images by running this cell.

#@markdown OR

#@markdown You can use the file manager on the left panel to upload (drag and drop) to INSTANCE_DIR (it uploads faster)

import os
from google.colab import files
import shutil

uploaded = files.upload()
for filename in uploaded.keys():
    dst_path = os.path.join(INSTANCE_DIR, filename)
    shutil.move(filename, dst_path)

# %% [markdown]
# ### Start training
#
# remove `--use_8bit_adam` flag in the cell below if you got more than equal to 18 GB VRAM.
#
# `--mixed_precision="fp16"` uses a little more VRAM for some reason but is 1.5-2x faster on GPUs with tensor cores, change it to `--mixed_precision="no"` if you face out of memory issues.

# %%
# !accelerate launch train_dreambooth.py \
  --pretrained_model_name_or_path=$MODEL_NAME --use_auth_token \
  --instance_data_dir=$INSTANCE_DIR \
  --class_data_dir=$CLASS_DIR \
  --output_dir=$OUTPUT_DIR \
  --with_prior_preservation --prior_loss_weight=1.0 \
  --instance_prompt="photo of sks {CLASS_NAME}" \
  --class_prompt="photo of a {CLASS_NAME}" \
  --seed=1337 \
  --resolution=512 \
  --center_crop \
  --train_batch_size=1 \
  --mixed_precision="fp16" \
  --use_8bit_adam \
  --gradient_accumulation_steps=1 \
  --learning_rate=5e-6 \
  --lr_scheduler="constant" \
  --lr_warmup_steps=0 \
  --num_class_images=12 \
  --sample_batch_size=4 \
  --max_train_steps=800
# Out:
# The following values were not passed to `accelerate launch` and had defaults used instead:
# 	`--num_processes` was set to a value of `1`
# 	`--num_machines` was set to a value of `1`
# 	`--mixed_precision` was set to a value of `'no'`
# 	`--num_cpu_threads_per_process` was set to `1` to improve out-of-box performance
# To avoid this warning pass in values for each of the problematic parameters or run `accelerate config`.
# Downloading: 100% 543/543 [00:00<00:00, 545kB/s]
# Fetching 16 files:   0% 0/16 [00:00<?, ?it/s]
# Downloading: 100% 342/342 [00:00<00:00, 298kB/s]
# Fetching 16 files:   6% 1/16 [00:02<00:34,  2.28s/it]
# Downloading: 100% 4.56k/4.56k [00:00<00:00, 3.82MB/s]
# Fetching 16 files:  19% 3/16 [00:04<00:18,  1.45s/it]
# Downloading:   0% 0.00/1.22G [00:00<?, ?B/s]
# Downloading:   1% 7.88M/1.22G [00:00<00:15, 78.8MB/s]
# Downloading:   1% 15.8M/1.22G [00:00<00:15, 77.9MB/s]
# Downloading:   2% 23.6M/1.22G [00:00<00:15, 77.0MB/s]
# Downloading:   3% 31.3M/1.22G [00:00<00:15, 75.1MB/s]
# Downloading:   3% 39.1M/1.22G [00:00<00:15, 76.2MB/s]
# Downloading:   4% 46.8M/1.22G [00:00<00:15, 76.5MB/s]
# Downloading:   4% 54.5M/1.22G [00:00<00:15, 76.6MB/s]
# Downloading:   5% 62.3M/1.22G [00:00<00:14, 77.1MB/s]
# Downloading:   6% 70.0M/1.22G [00:00<00:14, 76.7MB/s]
# Downloading:   6% 77.7M/1.22G [00:01<00:14, 76.8MB/s]
# Downloading:   7% 85.5M/1.22G [00:01<00:14, 77.1MB/s]
# Downloading:   8% 93.2M/1.22G [00:01<00:14, 75.9MB/s]
# Downloading:   8% 101M/1.22G [00:01<00:14, 77.2MB/s]
# Downloading:   9% 109M/1.22G [00:01<00:14, 75.6MB/s]
# Downloading:  10% 117M/1.22G [00:01<00:14, 75.9MB/s]
# Downloading:  10% 124M/1.22G [00:01<00:15, 72.3MB/s]
# Downloading:  11% 132M/1.22G [00:01<00:14, 74.4MB/s]
# Downloading:  11% 140M/1.22G [00:01<00:14, 74.6MB/s]
# Downloading:  12% 148M/1.22G [00:01<00:14, 75.8MB/s]
# Downloading:  13% 155M/1.22G [00:02<00:15, 69.6MB/s]
# Downloading:  13% 162M/1.22G [00:02<00:14, 70.4MB/s]
# Downloading:  14% 170M/1.22G [00:02<00:14, 73.1MB/s]
# Downloading:  15% 178M/1.22G [00:02<00:14, 71.9MB/s]
# Downloading:  15% 186M/1.22G [00:02<00:13, 73.6MB/s]
# Downloading:  16% 193M/1.22G [00:02<00:14, 70.8MB/s]
# Downloading:  16% 200M/1.22G [00:02<00:14, 71.5MB/s]
# Downloading:  17% 208M/1.22G [00:02<00:13, 72.5MB/s]
# Downloading:  18% 216M/1.22G [00:02<00:13, 74.8MB/s]
# Downloading:  18% 224M/1.22G [00:02<00:13, 75.8MB/s]
# Downloading:  19% 232M/1.22G [00:03<00:12, 76.8MB/s]
# Downloading:  20% 239M/1.22G [00:03<00:12, 76.9MB/s]
# Downloading:  20% 247M/1.22G [00:03<00:12, 77.1MB/s]
# Downloading:  21% 255M/1.22G [00:03<00:13, 70.8MB/s]
# Downloading:  22% 262M/1.22G [00:03<00:13, 70.0MB/s]
# Downloading:  22% 270M/1.22G [00:03<00:13, 72.4MB/s]
# Downloading:  23% 278M/1.22G [00:03<00:12, 74.7MB/s]
# Downloading:  24% 286M/1.22G [00:03<00:12, 76.5MB/s]
# Downloading:  24% 294M/1.22G [00:03<00:12, 71.9MB/s]
# Downloading:  25% 302M/1.22G [00:04<00:12, 74.3MB/s]
# Downloading:  25% 310M/1.22G [00:04<00:11, 75.8MB/s]
# Downloading:  26% 317M/1.22G [00:04<00:11, 76.0MB/s]
# Downloading:  27% 325M/1.22G [00:04<00:11, 77.2MB/s]
# Downloading:  27% 333M/1.22G [00:04<00:11, 75.3MB/s]
# Downloading:  28% 341M/1.22G [00:04<00:11, 76.2MB/s]
# Downloading:  29% 348M/1.22G [00:04<00:11, 75.7MB/s]
# Downloading:  29% 356M/1.22G [00:04<00:11, 72.6MB/s]
# Downloading:  84% 1.02G/1.22G [00:13<00:02, 75.1MB/s]
# Downloading:  85% 1.03G/1.22G [00:14<00:02, 75.3MB/s]
# Downloading:  85% 1.04G/1.22G [00:14<00:02, 76.3MB/s]
# Downloading:  86% 1.05G/1.22G [00:14<00:02, 72.1MB/s]
# Downloading:  87% 1.05G/1.22G [00:14<00:02, 72.1MB/s]
# Downloading:  87% 1.06G/1.22G [00:14<00:02, 73.1MB/s]
# Downloading:  88% 1.07G/1.22G [00:14<00:01, 74.6MB/s]
# Downloading:  88% 1.08G/1.22G [00:14<00:01, 74.7MB/s]
# Downloading:  89% 1.08G/1.22G [00:14<00:01, 68.8MB/s]
# Downloading:  90% 1.09G/1.22G [00:14<00:01, 72.6MB/s]
# Downloading:  90% 1.10G/1.22G [00:14<00:01, 73.8MB/s]
# Downloading:  91% 1.11G/1.22G [00:15<00:01, 74.9MB/s]
# Downloading:  92% 1.11G/1.22G [00:15<00:01, 66.2MB/s]
# Downloading:  92% 1.12G/1.22G [00:15<00:01, 68.2MB/s]
# Downloading:  93% 1.13G/1.22G [00:15<00:01, 70.5MB/s]
# Downloading:  93% 1.14G/1.22G [00:15<00:01, 70.8MB/s]
# Downloading:  94% 1.14G/1.22G [00:15<00:01, 52.4MB/s]
# Downloading:  95% 1.15G/1.22G [00:15<00:01, 58.0MB/s]
# Downloading:  95% 1.16G/1.22G [00:15<00:00, 63.5MB/s]
# Downloading:  96% 1.17G/1.22G [00:16<00:00, 66.1MB/s]
# Downloading:  97% 1.17G/1.22G [00:16<00:00, 69.4MB/s]
# Downloading:  97% 1.18G/1.22G [00:16<00:00, 72.5MB/s]
# Downloading:  98% 1.19G/1.22G [00:16<00:00, 74.2MB/s]
# Downloading:  99% 1.20G/1.22G [00:16<00:00, 75.1MB/s]
# Downloading:  99% 1.21G/1.22G [00:16<00:00, 76.5MB/s]
# Downloading: 100% 1.22G/1.22G [00:16<00:00, 73.0MB/s]
# Fetching 16 files:  25% 4/16 [00:22<01:25,  7.12s/it]
# Downloading: 100% 209/209 [00:00<00:00, 183kB/s]
# Fetching 16 files:  38% 6/16 [00:25<00:41,  4.12s/it]
# Downloading: 100% 592/592 [00:00<00:00, 527kB/s]
# Fetching 16 files:  44% 7/16 [00:28<00:31,  3.55s/it]
# Downloading:   0% 0.00/492M [00:00<?, ?B/s]
# Downloading:   1% 5.08M/492M [00:00<00:09, 50.8MB/s]
# Downloading:   2% 11.3M/492M [00:00<00:08, 57.3MB/s]
# Downloading:   4% 17.6M/492M [00:00<00:07, 60.1MB/s]
# Downloading:   5% 25.2M/492M [00:00<00:07, 66.2MB/s]
# Downloading:   7% 32.8M/492M [00:00<00:06, 69.7MB/s]
# Downloading:   8% 40.3M/492M [00:00<00:06, 71.5MB/s]
# Downloading:  10% 48.2M/492M [00:00<00:05, 74.1MB/s]
# Downloading:  11% 56.3M/492M [00:00<00:05, 76.4MB/s]
# Downloading:  13% 64.0M/492M [00:00<00:05, 76.6MB/s]
# Downloading:  15% 71.7M/492M [00:01<00:05, 76.2MB/s]
# Downloading:  16% 79.7M/492M [00:01<00:05, 77.4MB/s]
# Downloading:  18% 87.5M/492M [00:01<00:05, 68.0MB/s]
# Downloading:  19% 95.2M/492M [00:01<00:05, 70.6MB/s]
# Downloading:  21% 103M/492M [00:01<00:05, 72.7MB/s]
# Downloading:  22% 111M/492M [00:01<00:05, 73.8MB/s]
# Downloading:  24% 118M/492M [00:01<00:05, 70.9MB/s]
# Downloading:  26% 126M/492M [00:01<00:05, 72.8MB/s]
# Downloading:  27% 133M/492M [00:01<00:04, 73.2MB/s]
# Downloading:  29% 141M/492M [00:01<00:04, 73.9MB/s]
# Downloading:  30% 149M/492M [00:02<00:04, 75.2MB/s]
# Downloading:  32% 156M/492M [00:02<00:04, 71.6MB/s]
# Downloading:  33% 164M/492M [00:02<00:04, 71.8MB/s]
# Downloading:  35% 171M/492M [00:02<00:04, 72.9MB/s]
# Downloading:  36% 178M/492M [00:02<00:04, 73.0MB/s]
# Downloading:  38% 186M/492M [00:02<00:04, 65.9MB/s]
# Downloading:  39% 193M/492M [00:02<00:04, 69.1MB/s]
# Downloading:  41% 201M/492M [00:02<00:04, 70.5MB/s]
# Downloading:  42% 209M/492M [00:02<00:03, 72.3MB/s]
# Downloading:  44% 216M/492M [00:03<00:03, 73.9MB/s]
# Downloading:  45% 224M/492M [00:03<00:03, 74.6MB/s]
# Downloading:  47% 232M/492M [00:03<00:03, 75.6MB/s]
# Downloading:  49% 239M/492M [00:03<00:03, 73.5MB/s]
# Downloading:  50% 247M/492M [00:03<00:03, 70.8MB/s]
# Downloading:  52% 255M/492M [00:03<00:03, 73.3MB/s]
# Downloading:  53% 262M/492M [00:03<00:03, 74.3MB/s]
# Downloading:  55% 270M/492M [00:03<00:03, 73.8MB/s]
# Downloading:  56% 277M/492M [00:03<00:02, 74.7MB/s]
# Downloading:  58% 285M/492M [00:03<00:02, 69.7MB/s]
# Downloading:  59% 292M/492M [00:04<00:02, 69.3MB/s]
# Downloading:  61% 300M/492M [00:04<00:02, 71.0MB/s]
# Downloading:  62% 307M/492M [00:04<00:02, 72.5MB/s]
# Downloading:  64% 314M/492M [00:04<00:02, 72.6MB/s]
# Downloading:  65% 322M/492M [00:04<00:02, 70.4MB/s]
# Downloading:  67% 329M/492M [00:04<00:02, 71.3MB/s]
# Downloading:  68% 336M/492M [00:04<00:02, 71.4MB/s]
# Downloading:  70% 344M/492M [00:04<00:02, 72.8MB/s]
# Downloading:  71% 351M/492M [00:04<00:02, 69.2MB/s]
# Downloading:  73% 358M/492M [00:05<00:01, 69.2MB/s]
# Downloading:  74% 366M/492M [00:05<00:01, 71.2MB/s]
# Downloading:  76% 373M/492M [00:05<00:01, 72.3MB/s]
# Downloading:  77% 381M/492M [00:05<00:01, 74.4MB/s]
# Downloading:  79% 389M/492M [00:05<00:01, 73.7MB/s]
# Downloading:  80% 396M/492M [00:05<00:01, 73.8MB/s]
# Downloading:  82% 404M/492M [00:05<00:01, 75.5MB/s]
# Downloading:  84% 412M/492M [00:05<00:01, 76.9MB/s]
# Downloading:  85% 420M/492M [00:05<00:00, 75.5MB/s]
# Downloading:  87% 428M/492M [00:05<00:00, 76.5MB/s]
# Downloading:  88% 435M/492M [00:06<00:00, 76.6MB/s]
# Downloading:  90% 443M/492M [00:06<00:00, 70.1MB/s]
# Downloading:  91% 450M/492M [00:06<00:00, 67.0MB/s]
# Downloading:  93% 457M/492M [00:06<00:00, 67.6MB/s]
# Downloading:  94% 464M/492M [00:06<00:00, 69.7MB/s]
# Downloading:  96% 472M/492M [00:06<00:00, 72.0MB/s]
# Downloading:  98% 480M/492M [00:06<00:00, 74.2MB/s]
# Downloading: 100% 492M/492M [00:06<00:00, 72.3MB/s]
# Fetching 16 files:  50% 8/16 [00:36<00:39,  4.91s/it]
# Downloading:   0% 0.00/525k [00:00<?, ?B/s]
# Downloading:   2% 12.3k/525k [00:00<00:09, 52.7kB/s]
# Downloading:   7% 36.9k/525k [00:00<00:05, 83.5kB/s]
# Downloading:  18% 94.2k/525k [00:00<00:02, 157kB/s]
# Downloading:  38% 201k/525k [00:00<00:01, 275kB/s]
# Downloading: 100% 525k/525k [00:01<00:00, 447kB/s]
# Fetching 16 files:  56% 9/16 [00:39<00:31,  4.48s/it]
# Downloading: 100% 472/472 [00:00<00:00, 427kB/s]
# Fetching 16 files:  62% 10/16 [00:41<00:22,  3.81s/it]
# Downloading: 100% 806/806 [00:00<00:00, 683kB/s]
# Fetching 16 files:  69% 11/16 [00:44<00:16,  3.36s/it]
# Downloading:   0% 0.00/1.06M [00:00<?, ?B/s]
# Downloading:   3% 32.8k/1.06M [00:00<00:07, 144kB/s]
# Downloading:   9% 90.1k/1.06M [00:00<00:04, 207kB/s]
# Downloading:  18% 188k/1.06M [00:00<00:02, 309kB/s]
# Downloading:  36% 385k/1.06M [00:00<00:01, 528kB/s]
# Downloading: 100% 1.06M/1.06M [00:01<00:00, 925kB/s]
# Fetching 16 files:  75% 12/16 [00:47<00:13,  3.46s/it]
# Downloading: 100% 743/743 [00:00<00:00, 624kB/s]
# Fetching 16 files:  81% 13/16 [00:50<00:09,  3.10s/it]
# Downloading:   0% 0.00/3.44G [00:00<?, ?B/s]
# Downloading:   0% 7.34M/3.44G [00:00<00:46, 73.4MB/s]
# Downloading:   0% 15.0M/3.44G [00:00<00:45, 75.0MB/s]
# Downloading:   1% 22.8M/3.44G [00:00<00:44, 76.4MB/s]
# Downloading:   1% 30.4M/3.44G [00:00<00:44, 76.0MB/s]
# Downloading:   1% 38.0M/3.44G [00:00<00:45, 74.9MB/s]
# Downloading:   1% 45.6M/3.44G [00:00<00:44, 75.4MB/s]
# Downloading:   2% 53.4M/3.44G [00:00<00:44, 76.1MB/s]
# Downloading:   2% 61.4M/3.44G [00:00<00:43, 77.2MB/s]
# Downloading:   2% 69.2M/3.44G [00:00<00:43, 77.7MB/s]
# Downloading:   2% 77.0M/3.44G [00:01<00:43, 77.6MB/s]
# Downloading:   2% 84.9M/3.44G [00:01<00:42, 78.1MB/s]
# Downloading:   3% 92.8M/3.44G [00:01<00:43, 77.3MB/s]
# Downloading:   3% 101M/3.44G [00:01<00:42, 78.0MB/s]
# Downloading:   3% 109M/3.44G [00:01<00:42, 79.0MB/s]
# Downloading:   3% 117M/3.44G [00:01<00:42, 77.3MB/s]
# Downloading:   4% 125M/3.44G [00:01<00:48, 68.0MB/s]
# Downloading:   4% 132M/3.44G [00:01<00:47, 69.9MB/s]
# Downloading:   4% 140M/3.44G [00:01<00:46, 71.6MB/s]
# Downloading:   4% 148M/3.44G [00:01<00:44, 74.3MB/s]
# Downloading:   5% 155M/3.44G [00:02<00:46, 71.1MB/s]
# Downloading:   5% 164M/3.44G [00:02<00:43, 74.5MB/s]
# Downloading:   5% 172M/3.44G [00:02<00:42, 76.1MB/s]
# Downloading:   5% 179M/3.44G [00:02<00:43, 75.7MB/s]
# Downloading:   5% 187M/3.44G [00:02<00:44, 72.4MB/s]
# Downloading:   6% 195M/3.44G [00:02<00:43, 74.2MB/s]
# Downloading:   6% 202M/3.44G [00:02<00:43, 73.9MB/s]
# Downloading:   6% 210M/3.44G [00:02<00:42, 76.0MB/s]
# Downloading:   6% 218M/3.44G [00:02<00:42, 76.0MB/s]
# Downloading:   7% 226M/3.44G [00:03<00:43, 73.6MB/s]
# Downloading:   7% 234M/3.44G [00:03<00:42, 75.5MB/s]
# Downloading:   7% 242M/3.44G [00:03<00:41, 76.7MB/s]
# Downloading:   7% 250M/3.44G [00:03<00:40, 78.7MB/s]
# Downloading:   7% 258M/3.44G [00:03<00:46, 68.0MB/s]
# Downloading:   8% 266M/3.44G [00:03<00:44, 71.3MB/s]
# Downloading:   8% 273M/3.44G [00:03<00:44, 70.3MB/s]
# Downloading:   8% 282M/3.44G [00:03<00:42, 73.8MB/s]
# Downloading:   8% 290M/3.44G [00:03<00:41, 76.2MB/s]
# Downloading:   9% 298M/3.44G [00:03<00:40, 77.2MB/s]
# Downloading:   9% 306M/3.44G [00:04<00:40, 78.3MB/s]
# Downloading:   9% 314M/3.44G [00:04<00:39, 78.8MB/s]
# Downloading:   9% 322M/3.44G [00:04<00:42, 74.1MB/s]
# Downloading:  10% 330M/3.44G [00:04<00:40, 76.0MB/s]
# Downloading:  10% 338M/3.44G [00:04<00:39, 77.9MB/s]
# Downloading:  10% 346M/3.44G [00:04<00:39, 78.6MB/s]
# Downloading:  10% 354M/3.44G [00:04<00:44, 68.9MB/s]
# Downloading:  11% 361M/3.44G [00:04<00:44, 69.5MB/s]
# Downloading:  11% 369M/3.44G [00:04<00:42, 71.7MB/s]
# Downloading:  11% 377M/3.44G [00:05<00:41, 73.4MB/s]
# Downloading:  11% 385M/3.44G [00:05<00:40, 75.4MB/s]
# Downloading:  11% 393M/3.44G [00:05<00:39, 77.3MB/s]
# Downloading:  12% 401M/3.44G [00:05<00:39, 77.7MB/s]
# Downloading:  12% 409M/3.44G [00:05<00:39, 77.5MB/s]
# Downloading:  12% 417M/3.44G [00:05<00:38, 79.1MB/s]
# Downloading:  12% 425M/3.44G [00:05<00:38, 78.6MB/s]
# Downloading:  13% 433M/3.44G [00:05<00:38, 77.3MB/s]
# Downloading:  13% 441M/3.44G [00:05<00:38, 78.2MB/s]
# Downloading:  52% 1.77G/3.44G [00:23<00:22, 74.1MB/s]
# Downloading:  52% 1.78G/3.44G [00:23<00:21, 76.6MB/s]
# Downloading:  52% 1.79G/3.44G [00:23<00:21, 77.9MB/s]
# Downloading:  52% 1.80G/3.44G [00:24<00:21, 76.5MB/s]
# Downloading:  53% 1.81G/3.44G [00:24<00:21, 74.3MB/s]
# Downloading:  53% 1.81G/3.44G [00:24<00:23, 68.4MB/s]
# Downloading:  53% 1.82G/3.44G [00:24<00:23, 70.3MB/s]
# Downloading:  53% 1.83G/3.44G [00:24<00:21, 73.9MB/s]
# Downloading:  53% 1.84G/3.44G [00:24<00:20, 76.7MB/s]
# Downloading:  54% 1.84G/3.44G [00:24<00:20, 76.4MB/s]
# Downloading:  54% 1.85G/3.44G [00:24<00:20, 78.0MB/s]
# Downloading:  54% 1.86G/3.44G [00:24<00:20, 77.5MB/s]
# Downloading:  54% 1.87G/3.44G [00:25<00:20, 77.2MB/s]
# Downloading:  55% 1.88G/3.44G [00:25<00:20, 76.6MB/s]
# Downloading:  55% 1.88G/3.44G [00:25<00:20, 76.3MB/s]
# Downloading:  55% 1.89G/3.44G [00:25<00:20, 77.0MB/s]
# Downloading:  55% 1.90G/3.44G [00:25<00:19, 78.0MB/s]
# Downloading:  55% 1.91G/3.44G [00:25<00:21, 72.3MB/s]
# Downloading:  56% 1.91G/3.44G [00:25<00:21, 72.4MB/s]
# Downloading:  56% 1.92G/3.44G [00:25<00:20, 75.4MB/s]
# Downloading:  56% 1.93G/3.44G [00:25<00:19, 77.7MB/s]
# Downloading:  56% 1.94G/3.44G [00:25<00:19, 75.7MB/s]
# Downloading:  57% 1.95G/3.44G [00:26<00:19, 77.2MB/s]
# Downloading:  57% 1.96G/3.44G [00:26<00:19, 75.8MB/s]
# Downloading:  57% 1.96G/3.44G [00:26<00:19, 76.3MB/s]
# Downloading:  57% 1.97G/3.44G [00:26<00:18, 77.7MB/s]
# Downloading:  58% 1.98G/3.44G [00:26<00:22, 66.0MB/s]
# Downloading:  58% 1.99G/3.44G [00:26<00:20, 69.7MB/s]
# Downloading:  58% 1.99G/3.44G [00:26<00:20, 70.7MB/s]
# Downloading:  58% 2.00G/3.44G [00:26<00:19, 72.3MB/s]
# Downloading:  58% 2.01G/3.44G [00:26<00:19, 73.2MB/s]
# Downloading:  59% 2.02G/3.44G [00:27<00:19, 74.5MB/s]
# Downloading:  59% 2.02G/3.44G [00:27<00:19, 72.6MB/s]
# Downloading:  59% 2.03G/3.44G [00:27<00:18, 74.3MB/s]
# Downloading:  59% 2.04G/3.44G [00:27<00:18, 76.7MB/s]
# Downloading:  60% 2.05G/3.44G [00:27<00:18, 76.9MB/s]
# Downloading:  60% 2.06G/3.44G [00:27<00:19, 72.5MB/s]
# Downloading:  60% 2.06G/3.44G [00:27<00:18, 74.6MB/s]
# Downloading:  60% 2.07G/3.44G [00:27<00:18, 75.9MB/s]
# Downloading:  60% 2.08G/3.44G [00:27<00:18, 75.3MB/s]
# Downloading:  61% 2.09G/3.44G [00:27<00:18, 72.2MB/s]
# Downloading:  70% 2.40G/3.44G [00:35<00:14, 70.9MB/s]
# Downloading:  70% 2.40G/3.44G [00:35<00:14, 72.0MB/s]
# Downloading:  70% 2.41G/3.44G [00:35<00:14, 68.6MB/s]
# Downloading:  70% 2.42G/3.44G [00:35<00:16, 61.3MB/s]
# Downloading:  71% 2.43G/3.44G [00:35<00:15, 65.1MB/s]
# Downloading:  71% 2.43G/3.44G [00:35<00:14, 67.9MB/s]
# Downloading:  71% 2.44G/3.44G [00:35<00:14, 70.2MB/s]
# Downloading:  71% 2.45G/3.44G [00:35<00:13, 72.9MB/s]
# Downloading:  71% 2.46G/3.44G [00:36<00:13, 74.8MB/s]
# Downloading:  72% 2.46G/3.44G [00:36<00:13, 74.6MB/s]
# Downloading:  72% 2.47G/3.44G [00:36<00:12, 76.1MB/s]
# Downloading:  72% 2.48G/3.44G [00:36<00:12, 75.0MB/s]
# Downloading:  72% 2.49G/3.44G [00:36<00:12, 75.4MB/s]
# Downloading:  73% 2.49G/3.44G [00:36<00:12, 76.0MB/s]
# Downloading:  73% 2.50G/3.44G [00:36<00:12, 77.1MB/s]
# Downloading:  73% 2.51G/3.44G [00:36<00:12, 77.2MB/s]
# Downloading:  73% 2.52G/3.44G [00:36<00:11, 77.6MB/s]
# Downloading:  73% 2.53G/3.44G [00:36<00:11, 78.4MB/s]
# Downloading:  74% 2.53G/3.44G [00:37<00:13, 68.2MB/s]
# Downloading:  74% 2.54G/3.44G [00:37<00:12, 71.1MB/s]
# Downloading:  74% 2.55G/3.44G [00:37<00:12, 73.1MB/s]
# Downloading:  74% 2.56G/3.44G [00:37<00:12, 70.0MB/s]
# Downloading:  75% 2.56G/3.44G [00:37<00:12, 68.1MB/s]
# Downloading:  75% 2.57G/3.44G [00:37<00:12, 72.1MB/s]
# Downloading:  75% 2.58G/3.44G [00:37<00:11, 73.4MB/s]
# Downloading:  75% 2.59G/3.44G [00:37<00:11, 75.1MB/s]
# Downloading:  76% 2.60G/3.44G [00:37<00:11, 74.2MB/s]
# Downloading:  76% 2.60G/3.44G [00:38<00:11, 72.0MB/s]
# Downloading:  76% 2.61G/3.44G [00:38<00:11, 75.1MB/s]
# Downloading:  76% 2.62G/3.44G [00:38<00:10, 76.1MB/s]
# Downloading:  76% 2.63G/3.44G [00:38<00:10, 76.8MB/s]
# Downloading:  77% 2.64G/3.44G [00:38<00:11, 70.0MB/s]
# Downloading:  77% 2.64G/3.44G [00:38<00:11, 72.0MB/s]
# Downloading:  77% 2.65G/3.44G [00:38<00:10, 73.4MB/s]
# Downloading:  77% 2.66G/3.44G [00:38<00:10, 75.0MB/s]
# Downloading:  78% 2.67G/3.44G [00:38<00:10, 71.1MB/s]
# Downloading:  78% 2.67G/3.44G [00:38<00:10, 72.0MB/s]
# Downloading:  78% 2.68G/3.44G [00:39<00:10, 73.7MB/s]
# Downloading:  78% 2.69G/3.44G [00:39<00:09, 75.5MB/s]
# Downloading:  78% 2.70G/3.44G [00:39<00:10, 70.9MB/s]
# Downloading:  79% 2.70G/3.44G [00:39<00:10, 70.8MB/s]
# Downloading:  79% 2.71G/3.44G [00:39<00:10, 72.4MB/s]
# Downloading:  79% 2.72G/3.44G [00:39<00:09, 73.4MB/s]
# Downloading:  79% 2.73G/3.44G [00:39<00:09, 75.3MB/s]
# Downloading:  80% 2.73G/3.44G [00:39<00:09, 70.9MB/s]
# Downloading:  80% 2.74G/3.44G [00:39<00:09, 71.6MB/s]
# Downloading:  80% 2.75G/3.44G [00:40<00:09, 72.1MB/s]
# Downloading:  80% 2.76G/3.44G [00:40<00:09, 73.0MB/s]
# Downloading:  80% 2.76G/3.44G [00:40<00:08, 75.0MB/s]
# Downloading:  81% 2.77G/3.44G [00:40<00:12, 52.9MB/s]
# Downloading:  81% 2.78G/3.44G [00:40<00:11, 59.0MB/s]
# Downloading:  81% 2.79G/3.44G [00:40<00:10, 64.0MB/s]
# Downloading:  81% 2.80G/3.44G [00:40<00:09, 66.8MB/s]
# Downloading:  82% 2.80G/3.44G [00:40<00:10, 62.8MB/s]
# Downloading:  82% 2.81G/3.44G [00:40<00:09, 63.9MB/s]
# Downloading:  82% 2.82G/3.44G [00:41<00:09, 64.4MB/s]
# Downloading:  82% 2.82G/3.44G [00:41<00:09, 67.7MB/s]
# Downloading:  82% 2.83G/3.44G [00:41<00:08, 69.8MB/s]
# Downloading:  83% 2.84G/3.44G [00:41<00:08, 70.1MB/s]
# Downloading:  83% 2.85G/3.44G [00:41<00:08, 72.1MB/s]
# Downloading:  83% 2.85G/3.44G [00:41<00:08, 72.9MB/s]
# Downloading:  83% 2.86G/3.44G [00:41<00:07, 75.1MB/s]
# Downloading:  83% 2.87G/3.44G [00:41<00:07, 76.1MB/s]
# Downloading:  84% 2.88G/3.44G [00:41<00:08, 69.9MB/s]
# Downloading:  84% 2.88G/3.44G [00:42<00:08, 67.2MB/s]
# Downloading:  84% 2.89G/3.44G [00:42<00:07, 70.4MB/s]
# Downloading:  84% 2.90G/3.44G [00:42<00:07, 71.7MB/s]
# Downloading:  85% 2.91G/3.44G [00:42<00:07, 74.6MB/s]
# Downloading:  85% 2.92G/3.44G [00:43<00:32, 16.0MB/s]
# Downloading:  85% 2.92G/3.44G [00:43<00:24, 20.8MB/s]
# Downloading:  85% 2.93G/3.44G [00:43<00:21, 24.0MB/s]
# Downloading:  85% 2.93G/3.44G [00:44<00:37, 13.4MB/s]
# Downloading:  86% 2.94G/3.44G [00:45<00:27, 18.2MB/s]
# Downloading:  86% 2.95G/3.44G [00:45<00:20, 24.2MB/s]
# Downloading:  86% 2.96G/3.44G [00:45<00:15, 30.3MB/s]
# Downloading:  86% 2.96G/3.44G [00:46<00:32, 14.6MB/s]
# Downloading:  86% 2.97G/3.44G [00:46<00:23, 19.6MB/s]
# Downloading:  87% 2.98G/3.44G [00:46<00:17, 25.8MB/s]
# Downloading:  87% 2.98G/3.44G [00:46<00:14, 30.9MB/s]
# Downloading:  87% 2.99G/3.44G [00:47<00:30, 14.7MB/s]
# Downloading:  87% 3.00G/3.44G [00:47<00:22, 19.6MB/s]
# Downloading:  87% 3.01G/3.44G [00:47<00:16, 25.9MB/s]
# Downloading:  88% 3.01G/3.44G [00:47<00:13, 30.7MB/s]
# Downloading:  88% 3.02G/3.44G [00:49<00:40, 10.3MB/s]
# Downloading:  88% 3.03G/3.44G [00:49<00:29, 13.9MB/s]
# Downloading:  88% 3.03G/3.44G [00:49<00:23, 17.5MB/s]
# Downloading:  88% 3.04G/3.44G [00:50<00:37, 10.8MB/s]
# Downloading:  89% 3.04G/3.44G [00:50<00:25, 15.2MB/s]
# Downloading:  89% 3.05G/3.44G [00:50<00:18, 21.0MB/s]
# Downloading:  89% 3.06G/3.44G [00:51<00:31, 12.2MB/s]
# Downloading:  89% 3.06G/3.44G [00:52<00:22, 16.7MB/s]
# Downloading:  89% 3.07G/3.44G [00:52<00:16, 22.4MB/s]
# Downloading:  90% 3.08G/3.44G [00:52<00:24, 15.0MB/s]
# Downloading:  90% 3.08G/3.44G [00:53<00:24, 14.6MB/s]
# Downloading:  90% 3.09G/3.44G [00:53<00:17, 19.9MB/s]
# Downloading:  90% 3.10G/3.44G [00:53<00:13, 26.2MB/s]
# Downloading:  90% 3.10G/3.44G [00:53<00:10, 32.0MB/s]
# Downloading:  90% 3.11G/3.44G [00:53<00:08, 38.1MB/s]
# Downloading:  91% 3.12G/3.44G [00:53<00:06, 46.7MB/s]
# Downloading:  91% 3.13G/3.44G [00:53<00:05, 53.0MB/s]
# Downloading:  91% 3.13G/3.44G [00:53<00:06, 48.5MB/s]
# Downloading:  91% 3.14G/3.44G [00:54<00:05, 53.5MB/s]
# Downloading:  92% 3.15G/3.44G [00:54<00:04, 59.2MB/s]
# Downloading:  92% 3.16G/3.44G [00:54<00:04, 62.5MB/s]
# Downloading:  92% 3.16G/3.44G [00:54<00:04, 65.5MB/s]
# Downloading:  92% 3.17G/3.44G [00:54<00:03, 69.4MB/s]
# Downloading:  92% 3.18G/3.44G [00:54<00:03, 70.6MB/s]
# Downloading:  93% 3.19G/3.44G [00:54<00:04, 50.9MB/s]
# Downloading:  93% 3.19G/3.44G [00:54<00:04, 56.4MB/s]
# Downloading:  93% 3.20G/3.44G [00:55<00:03, 60.5MB/s]
# Downloading:  93% 3.21G/3.44G [00:55<00:03, 64.8MB/s]
# Downloading:  94% 3.21G/3.44G [00:55<00:03, 67.0MB/s]
# Downloading:  94% 3.22G/3.44G [00:55<00:03, 69.7MB/s]
# Downloading:  94% 3.23G/3.44G [00:55<00:02, 72.2MB/s]
# Downloading:  94% 3.24G/3.44G [00:55<00:02, 73.0MB/s]
# Downloading:  94% 3.25G/3.44G [00:55<00:02, 74.0MB/s]
# Downloading:  95% 3.25G/3.44G [00:55<00:02, 62.1MB/s]
# Downloading:  95% 3.26G/3.44G [00:55<00:02, 63.0MB/s]
# Downloading:  95% 3.27G/3.44G [00:55<00:02, 65.8MB/s]
# Downloading:  95% 3.27G/3.44G [00:56<00:02, 67.7MB/s]
# Downloading:  95% 3.28G/3.44G [00:56<00:02, 71.1MB/s]
# Downloading:  96% 3.29G/3.44G [00:56<00:02, 71.5MB/s]
# Downloading:  96% 3.30G/3.44G [00:56<00:01, 74.0MB/s]
# Downloading:  96% 3.31G/3.44G [00:56<00:01, 75.1MB/s]
# Downloading:  96% 3.31G/3.44G [00:56<00:01, 73.6MB/s]
# Downloading:  97% 3.32G/3.44G [00:56<00:01, 65.3MB/s]
# Downloading:  97% 3.33G/3.44G [00:56<00:01, 67.3MB/s]
# Downloading:  97% 3.34G/3.44G [00:56<00:01, 70.3MB/s]
# Downloading:  97% 3.34G/3.44G [00:57<00:01, 66.1MB/s]
# Downloading:  97% 3.35G/3.44G [00:57<00:01, 69.6MB/s]
# Downloading:  98% 3.36G/3.44G [00:57<00:01, 73.0MB/s]
# Downloading:  98% 3.37G/3.44G [00:57<00:00, 74.6MB/s]
# Downloading:  98% 3.37G/3.44G [00:57<00:00, 70.1MB/s]
# Downloading:  98% 3.38G/3.44G [00:57<00:00, 71.9MB/s]
# Downloading:  99% 3.39G/3.44G [00:57<00:00, 73.9MB/s]
# Downloading:  99% 3.40G/3.44G [00:57<00:00, 72.1MB/s]
# Downloading:  99% 3.40G/3.44G [00:57<00:00, 72.4MB/s]
# Downloading:  99% 3.41G/3.44G [00:58<00:00, 70.8MB/s]
# Downloading:  99% 3.42G/3.44G [00:58<00:00, 70.4MB/s]
# Downloading: 100% 3.43G/3.44G [00:58<00:00, 70.5MB/s]
# Downloading: 100% 3.44G/3.44G [00:58<00:00, 58.9MB/s]
# Fetching 16 files:  88% 14/16 [01:49<00:40, 20.10s/it]
# Downloading: 100% 522/522 [00:00<00:00, 461kB/s]
# Fetching 16 files:  94% 15/16 [01:52<00:14, 14.74s/it]
# Downloading:   0% 0.00/335M [00:00<?, ?B/s]
# Downloading:   2% 6.59M/335M [00:00<00:04, 65.9MB/s]
# Downloading:   4% 13.7M/335M [00:00<00:04, 68.8MB/s]
# Downloading:   6% 21.2M/335M [00:00<00:04, 71.6MB/s]
# Downloading:   9% 28.7M/335M [00:00<00:04, 73.2MB/s]
# Downloading:  11% 36.1M/335M [00:00<00:04, 72.5MB/s]
# Downloading:  13% 44.2M/335M [00:00<00:03, 75.5MB/s]
# Downloading:  15% 51.7M/335M [00:00<00:04, 67.5MB/s]
# Downloading:  18% 58.8M/335M [00:00<00:04, 68.4MB/s]
# Downloading:  20% 66.4M/335M [00:00<00:03, 70.8MB/s]
# Downloading:  22% 73.6M/335M [00:01<00:03, 71.1MB/s]
# Downloading:  24% 80.8M/335M [00:01<00:03, 71.1MB/s]
# Downloading:  26% 88.6M/335M [00:01<00:03, 73.3MB/s]
# Downloading:  29% 96.2M/335M [00:01<00:03, 74.0MB/s]
# Downloading:  31% 104M/335M [00:01<00:03, 74.5MB/s]
# Downloading:  33% 112M/335M [00:01<00:02, 76.6MB/s]
# Downloading:  36% 120M/335M [00:01<00:03, 69.0MB/s]
# Downloading:  38% 127M/335M [00:01<00:02, 70.4MB/s]
# Downloading:  40% 135M/335M [00:01<00:02, 73.7MB/s]
# Downloading:  43% 143M/335M [00:01<00:02, 75.3MB/s]
# Downloading:  45% 151M/335M [00:02<00:02, 72.5MB/s]
# Downloading:  47% 158M/335M [00:02<00:02, 70.3MB/s]
# Downloading:  50% 166M/335M [00:02<00:02, 73.1MB/s]
# Downloading:  52% 174M/335M [00:02<00:02, 74.0MB/s]
# Downloading:  54% 181M/335M [00:02<00:02, 65.8MB/s]
# Downloading:  56% 188M/335M [00:02<00:02, 67.7MB/s]
# Downloading:  59% 196M/335M [00:02<00:01, 70.1MB/s]
# Downloading:  61% 204M/335M [00:02<00:01, 73.2MB/s]
# Downloading:  63% 212M/335M [00:02<00:01, 73.6MB/s]
# Downloading:  65% 219M/335M [00:03<00:01, 74.0MB/s]
# Downloading:  68% 227M/335M [00:03<00:01, 74.9MB/s]
# Downloading:  70% 234M/335M [00:03<00:01, 74.9MB/s]
# Downloading:  72% 242M/335M [00:03<00:01, 76.5MB/s]
# Downloading:  75% 250M/335M [00:03<00:01, 77.3MB/s]
# Downloading:  77% 258M/335M [00:03<00:01, 75.0MB/s]
# Downloading:  80% 266M/335M [00:03<00:00, 76.6MB/s]
# Downloading:  82% 274M/335M [00:03<00:00, 78.0MB/s]
# Downloading:  84% 282M/335M [00:03<00:00, 77.2MB/s]
# Downloading:  87% 290M/335M [00:03<00:00, 77.5MB/s]
# Downloading:  89% 298M/335M [00:04<00:00, 68.3MB/s]
# Downloading:  91% 305M/335M [00:04<00:00, 71.0MB/s]
# Downloading:  93% 313M/335M [00:04<00:00, 70.8MB/s]
# Downloading:  96% 320M/335M [00:04<00:00, 66.4MB/s]
# Downloading: 100% 335M/335M [00:04<00:00, 72.6MB/s]
# Fetching 16 files: 100% 16/16 [01:57<00:00,  7.36s/it]
# Generating class images: 100% 3/3 [01:43<00:00, 34.45s/it]
# Downloading: 100% 1.06M/1.06M [00:01<00:00, 916kB/s]
# Downloading: 100% 525k/525k [00:00<00:00, 559kB/s]
# Downloading: 100% 472/472 [00:00<00:00, 396kB/s]
# Downloading: 100% 806/806 [00:00<00:00, 687kB/s]
# Downloading: 100% 592/592 [00:00<00:00, 520kB/s]
# Downloading: 100% 492M/492M [00:11<00:00, 42.4MB/s]
#
# ===================================BUG REPORT===================================
# Welcome to bitsandbytes. For bug reports, please submit your error trace to: https://github.com/TimDettmers/bitsandbytes/issues
# For effortless bug reporting copy-paste your error into this form: https://docs.google.com/forms/d/e/1FAIpQLScPB8emS3Thkp66nvqwmjTEgxp8Y9ufuWTzFyr9kJ5AoI47dQ/viewform?usp=sf_link
# ================================================================================
# /usr/local/lib/python3.7/dist-packages/bitsandbytes/cuda_setup/paths.py:99: UserWarning: /usr/lib64-nvidia did not contain libcudart.so as expected! Searching further paths...
#   f'{candidate_env_vars["LD_LIBRARY_PATH"]} did not contain '
# /usr/local/lib/python3.7/dist-packages/bitsandbytes/cuda_setup/paths.py:21: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('"172.28.0.3","jupyterArgs"'), PosixPath('{"kernelManagerProxyPort"'), PosixPath('true}'), PosixPath('"/usr/local/bin/dap_multiplexer","enableLsp"'), PosixPath('6000,"kernelManagerProxyHost"'), PosixPath('["--ip=172.28.0.2"],"debugAdapterMultiplexerPath"')}
#   "WARNING: The following directories listed in your path were found to "
# /usr/local/lib/python3.7/dist-packages/bitsandbytes/cuda_setup/paths.py:21: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//ipykernel.pylab.backend_inline'), PosixPath('module')}
#   "WARNING: The following directories listed in your path were found to "
# /usr/local/lib/python3.7/dist-packages/bitsandbytes/cuda_setup/paths.py:21: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('/env/python')}
#   "WARNING: The following directories listed in your path were found to "
# CUDA_SETUP: WARNING! libcudart.so not found in any environmental path. Searching /usr/local/cuda/lib64...
# CUDA SETUP: CUDA runtime path found: /usr/local/cuda/lib64/libcudart.so
# CUDA SETUP: Highest compute capability among GPUs detected: 7.5
# CUDA SETUP: Detected CUDA version 111
# CUDA SETUP: Loading binary /usr/local/lib/python3.7/dist-packages/bitsandbytes/libbitsandbytes_cuda111.so...
# Steps: 100% 800/800 [20:38<00:00,  1.54s/it, loss=0.725, lr=5e-6]
# Fetching 16 files: 100% 16/16 [00:00<00:00, 2835.79it/s]
# Steps: 100% 800/800 [21:15<00:00,  1.59s/it, loss=0.725, lr=5e-6]

# %% [markdown]
# ## Inference

# %%
import torch
from torch import autocast
from diffusers import StableDiffusionPipeline
from IPython.display import display

model_path = OUTPUT_DIR             # If you want to use previously trained model saved in gdrive, replace this with the full path of model in gdrive

pipe = StableDiffusionPipeline.from_pretrained(model_path, torch_dtype=torch.float16).to("cuda")
g_cuda = None
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# Moving 0 files to the new cache system
# 0it [00:00, ?it/s]

# %%
#@markdown Can set random seed here for reproducibility.
g_cuda = torch.Generator(device='cuda')
seed = 523662 #@param {type:"number"}
g_cuda.manual_seed(seed)

# %%
#@title Run for generating images.

prompt = "sks woman pastel pink big bouffant hair bow satin pussy bridal blouse huge ruffle knickers wide 50s double petticoat puffy diaper nappy pinup stepford wife pink pinafore dress high detail sissy 4k 8k uhd intricate " #@param {type:"string"}
num_samples = 10 #@param {type:"number"}

with autocast("cuda"), torch.inference_mode():
    images = pipe([prompt] * num_samples, height=512, width=512, num_inference_steps=200, guidance_scale=9, generator=g_cuda).images

for img in images:
    display(img)
# Out:
#   0%|          | 0/201 [00:00<?, ?it/s]

# %%
#@markdown Run Gradio UI for generating images.
import gradio as gr

def inference(prompt, num_samples, height=512, width=512, num_inference_steps=50, guidance_scale=7.5):
    with torch.autocast("cuda"), torch.inference_mode():
        return pipe(
            [prompt]*int(num_samples), height=int(height), width=int(width),
            num_inference_steps=int(num_inference_steps), guidance_scale=guidance_scale,
            generator=g_cuda
            ).images

with gr.Blocks() as demo:
    with gr.Row():
        with gr.Column():
            prompt = gr.Textbox(label="Prompt", value="photo of sks guy, digital painting")
            run = gr.Button(value="Generate")
            with gr.Row():
                num_samples = gr.Number(label="Number of Samples", value=4)
                guidance_scale = gr.Number(label="Guidance Scale", value=7.5)
            with gr.Row():
                height = gr.Number(label="Height", value=512)
                width = gr.Number(label="Width", value=512)
            num_inference_steps = gr.Slider(label="Steps", value=50)
        with gr.Column():
            gallery = gr.Gallery()

    run.click(inference, inputs=[prompt, num_samples, height, width, num_inference_steps, guidance_scale], outputs=gallery)

demo.launch(debug=True)
# Out:
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# Running on public URL: https://16116.gradio.app
#
# This share link expires in 72 hours. For free permanent hosting, check out Spaces: https://huggingface.co/spaces
# <div><iframe src="https://16116.gradio.app" width="900" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
#   0%|          | 0/51 [00:00<?, ?it/s]
# Keyboard interruption in main thread... closing server.
# (<gradio.routes.App at 0x7f592a118a10>,
#  'http://127.0.0.1:7860/',
#  'https://16116.gradio.app')
